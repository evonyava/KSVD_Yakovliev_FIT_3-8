# %% [markdown]
# <a href="https://colab.research.google.com/github/evonyava/KSVD_Yakovliev_FIT_3-8/blob/main/%D0%9B%D0%A06_%D0%AF%D0%BA%D0%BE%D0%B2%D0%BB%D1%94%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import math

class LSystem2D:
    def __init__(self, axiom, width, length, angle):
        self.axiom = axiom
        self.state = axiom
        self.width = width
        self.length = length
        self.angle = angle
        self.rules = {}

    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value

    def generate_path(self, n_iter):
        for _ in range(n_iter):
            new_state = ""
            for char in self.state:
                new_state += self.rules.get(char, char)
            self.state = new_state

    def draw_turtle(self, start_pos=(0, 0), start_angle=0):
        x, y = start_pos
        current_angle = start_angle
        stack = []
        lines_x, lines_y = [], []

        for move in self.state:
            if move == 'F':
                new_x = x + self.length * math.cos(math.radians(current_angle))
                new_y = y + self.length * math.sin(math.radians(current_angle))
                lines_x.extend([x, new_x, None])
                lines_y.extend([y, new_y, None])
                x, y = new_x, new_y
            elif move == '+':
                current_angle += self.angle
            elif move == '-':
                current_angle -= self.angle
            elif move == '[':
                stack.append((x, y, current_angle))
            elif move == ']':
                x, y, current_angle = stack.pop()

        plt.figure(figsize=(8, 8))
        plt.plot(lines_x, lines_y, linewidth=self.width, color='magenta')
        plt.axis('equal')
        plt.axis('off')
        plt.show()

axiom = "X+X+X+X+X+X+X+X"
angle = 45
l_sys = LSystem2D(axiom, 1, 5, angle)
l_sys.add_rules(("X", "F-[[X]+X]+F[+FX]-X"), ("F", "FF"))
l_sys.generate_path(4)
l_sys.draw_turtle()

# %%
import matplotlib.pyplot as plt
import math

class LSystem2D:
    def __init__(self, axiom, width, length, angle):
        self.axiom = axiom
        self.state = axiom
        self.width = width
        self.length = length
        self.angle = angle
        self.rules = {}

    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value

    def generate_path(self, n_iter):
        for _ in range(n_iter):
            new_state = ""
            for char in self.state:
                new_state += self.rules.get(char, char)
            self.state = new_state

    def draw_turtle(self, start_pos=(0, 0), start_angle=0):
        x, y = start_pos
        current_angle = start_angle
        lines_x, lines_y = [], []

        for move in self.state:
            if move == 'F':
                new_x = x + self.length * math.cos(math.radians(current_angle))
                new_y = y + self.length * math.sin(math.radians(current_angle))
                lines_x.extend([x, new_x, None])
                lines_y.extend([y, new_y, None])
                x, y = new_x, new_y
            elif move == '+':
                current_angle += self.angle
            elif move == '-':
                current_angle -= self.angle

        plt.figure(figsize=(8, 8))
        plt.plot(lines_x, lines_y, linewidth=self.width, color='blue')
        plt.axis('equal')
        plt.axis('off')
        plt.show()

axiom = "F"
angle = 60
l_sys = LSystem2D(axiom, 1, 5, angle)
l_sys.add_rules(("F", "F-G+F+G-F-G+F+G+"), ("G", "GG"))
l_sys.generate_path(6)
l_sys.draw_turtle()

# %%
import matplotlib.pyplot as plt
import math

class LSystem2D:
    def __init__(self, axiom, width, length, angle):
        self.axiom = axiom
        self.state = axiom
        self.width = width
        self.length = length
        self.angle = angle
        self.rules = {}

    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value

    def generate_path(self, n_iter):
        for _ in range(n_iter):
            new_state = ""
            for char in self.state:
                new_state += self.rules.get(char, char)
            self.state = new_state

    def draw_turtle(self, start_pos=(0, 0), start_angle=0):
        x, y = start_pos
        current_angle = start_angle
        lines_x, lines_y = [], []

        for move in self.state:
            if move == 'F':
                new_x = x + self.length * math.cos(math.radians(current_angle))
                new_y = y + self.length * math.sin(math.radians(current_angle))
                lines_x.extend([x, new_x, None])
                lines_y.extend([y, new_y, None])
                x, y = new_x, new_y
            elif move == '+':
                current_angle += self.angle
            elif move == '-':
                current_angle -= self.angle

        plt.figure(figsize=(8, 8))
        plt.plot(lines_x, lines_y, linewidth=self.width, color='darkblue')
        plt.axis('equal')
        plt.axis('off')
        plt.show()

axiom = "A"
angle = 90
l_sys = LSystem2D(axiom, 1, 5, angle)
l_sys.add_rules(("A", "-BF+AFA+FB-"), ("B", "+AF-BFB-FA+"))
l_sys.generate_path(6)
l_sys.draw_turtle()
